# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df  = df.drop(columns='ChestPain')

# %%
df
# Out:
#      Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0             1   63    1     145   233    1        2    150      0      2.3
# 1             2   67    1     160   286    0        2    108      1      1.5
# 2             3   67    1     120   229    0        2    129      1      2.6
# 3             4   37    1     130   250    0        0    187      0      3.5
# 4             5   41    0     130   204    0        2    172      0      1.4
# ..          ...  ...  ...     ...   ...  ...      ...    ...    ...      ...
# 298         299   45    1     110   264    0        0    132      0      1.2
# 299         300   68    1     144   193    1        0    141      0      3.4
# 300         301   57    1     130   131    0        0    115      1      1.2
# 301         302   57    0     130   236    0        2    174      0      0.0
# 302         303   38    1     138   175    0        0    173      0      0.0
#
#      Slope   Ca        Thal  AHD
# ...

# %%
df  = df.drop(columns='Thal')
df
# Out:
#      Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0             1   63    1     145   233    1        2    150      0      2.3
# 1             2   67    1     160   286    0        2    108      1      1.5
# 2             3   67    1     120   229    0        2    129      1      2.6
# 3             4   37    1     130   250    0        0    187      0      3.5
# 4             5   41    0     130   204    0        2    172      0      1.4
# ..          ...  ...  ...     ...   ...  ...      ...    ...    ...      ...
# 298         299   45    1     110   264    0        0    132      0      1.2
# 299         300   68    1     144   193    1        0    141      0      3.4
# 300         301   57    1     130   131    0        0    115      1      1.2
# 301         302   57    0     130   236    0        2    174      0      0.0
# 302         303   38    1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  AHD
# 0        3  0.0   No
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(df['Sex'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
df['cc'] = le.transform(df.Sex)

# %%
df
# Out:
#      Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0             1   63    1     145   233    1        2    150      0      2.3
# 1             2   67    1     160   286    0        2    108      1      1.5
# 2             3   67    1     120   229    0        2    129      1      2.6
# 3             4   37    1     130   250    0        0    187      0      3.5
# 4             5   41    0     130   204    0        2    172      0      1.4
# ..          ...  ...  ...     ...   ...  ...      ...    ...    ...      ...
# 298         299   45    1     110   264    0        0    132      0      1.2
# 299         300   68    1     144   193    1        0    141      0      3.4
# 300         301   57    1     130   131    0        0    115      1      1.2
# 301         302   57    0     130   236    0        2    174      0      0.0
# 302         303   38    1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  AHD  cc
# ...

# %%
for i in df.columns:
    
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#      Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0             0   29    1      31    64    1        2     49      0       22
# 1             1   33    1      40   111    0        2     10      1       15
# 2             2   33    1      14    60    0        2     29      1       25
# 3             3    3    1      22    80    0        0     84      0       32
# 4             4    7    0      22    35    0        2     71      0       14
# ..          ...  ...  ...     ...   ...  ...      ...    ...    ...      ...
# 298         298   11    1       8    93    0        0     32      0       12
# 299         299   34    1      30    26    1        0     40      0       31
# 300         300   23    1      22     1    0        0     16      1       12
# 301         301   23    0      22    67    0        2     73      0        0
# 302         302    4    1      27    13    0        0     72      0        0
#
#      Slope  Ca  AHD  cc
# ...

# %%
df.corr()
# Out:
#             Unnamed: 0       Age       Sex    RestBP      Chol       Fbs  \
# Unnamed: 0    1.000000 -0.004449 -0.070849 -0.031312 -0.094883 -0.039471
# Age          -0.004449  1.000000 -0.095970  0.290775  0.201511  0.119988
# Sex          -0.070849 -0.095970  1.000000 -0.062893 -0.164247  0.047862
# RestBP       -0.031312  0.290775 -0.062893  1.000000  0.148579  0.166344
# Chol         -0.094883  0.201511 -0.164247  0.148579  1.000000  0.013546
# Fbs          -0.039471  0.119988  0.047862  0.166344  0.013546  1.000000
# RestECG      -0.150232  0.150546  0.021647  0.146188  0.164378  0.069564
# MaxHR        -0.100523 -0.391774 -0.048829 -0.046498 -0.024010 -0.005799
# ExAng        -0.000402  0.089994  0.146201  0.052690  0.082206  0.025665
# Oldpeak      -0.131637  0.214229  0.111331  0.171201  0.034326  0.012743
# Slope        -0.028458  0.162098  0.037533  0.101856 -0.009738  0.059894
# Ca            0.085926  0.300369  0.116008  0.100962  0.100020  0.145757
# ...

# %%
import seaborn as sns

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
sns.set(rc = {'figure.figsize':(15,15)}) 
plt.show()

# %%
df.corrwith(df['RestBP']).sort_values(ascending=False).plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
y = df['RestBP']

# %%
X = df[df.columns[1:]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report

# %%
#model1 = LogisticRegression(random_state =100,C=1.2, penalty='l2')

# %%
c = [1,2,3,4,5]
sol = ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]



for i,j in zip(C,solver):
    
    model1=LogisticRegression(solver = j,C = i)
    model1.fit(X_train,y_train)
    y_predTr = model1.predict(X_train)
    y_predTe = model1.predict(X_test) 
    print(confusion_matrix(y_train,y_predTr))
    c = classification_report(y_train,y_predTr)
    print(c)
    print(70*'-')
    print(confusion_matrix(y_test,y_predTe))
    c = classification_report(y_test,y_predTe)
    print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HAMNAI~1\AppData\Local\Temp/ipykernel_24172/130485964.py in <module>
#       4
#       5
# ----> 6 for i,j in zip(C,solver):
#       7
#       8     model1=LogisticRegression(solver = j,C = i)
#
# NameError: name 'C' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import tree

# %%
model2 = DecisionTreeClassifier(criterion='entropy')
model2.fit(X_train,y_train)
y_predTr = model2.predict(X_train)
y_predTe = model2.predict(X_test)
print(confusion_matrix(y_train,y_predTr))
c = classification_report(y_train,y_predTr)
print(c)
print(30*'-')
print(confusion_matrix(y_test,y_predTe))
c = classification_report(y_test,y_predTe)
print(c)

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20))
tree.plot_tree(model2, feature_names=X.columns, class_names='Sex', filled = True)
plt.savefig('my.pdf')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3 = RandomForestClassifier(n_estimators=100)
model3.fit(X_train,y_train)
y_predTr = model3.predict(X_train)
y_predTe = model3.predict(X_test)
print(confusion_matrix(y_train,y_predTr))
c = classification_report(y_train,y_predTr)
print(c)
print(30*'-')
print(confusion_matrix(y_test,y_predTe))
c = classification_report(y_test,y_predTe)
print(c)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
mod_lis = [model1,model2,model3]

# %%
def training_resyl(li):
    for model in li:
        model = RandomForestClassifier(n_estimators=100)
        model.fit(X_train,y_train)
        y_predTr = model.predict(X_train)
        y_predTe = model.predict(X_test)
        print(confusion_matrix(y_train,y_predTr))
        c = classification_report(y_train,y_predTr)
        print(c)
        print(10*'-')
        print(confusion_matrix(y_test,y_predTe))
        c = classification_report(y_test,y_predTe)
        print(c)
        plot_confusion_matrix(model, X_test, y_test)  
        plt.show()
        
        print(40*'*-*')

# %%
training_resyl(mod_lis)
