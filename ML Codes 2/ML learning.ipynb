# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df  = df.drop(columns='PassengerId')

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df.columns:
    
    df[i] = le.fit_transform(df[i])

# %%
le = LabelEncoder()

# %%
le.fit(df['Sex'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['cc'] = le.transform(df.Sex)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  cc
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S   1
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C   0
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S   0
# 3    female  35.0      1      0            113803  53.1000  C123        S   0
# 4      male  35.0      0      0            373450   8.0500   NaN        S   1
# ..      ...   ...    ...    ...               ...      ...   ...      ...  ..
# 886    male  27.0      0      0            211536  13.0000   NaN        S   1
# 887  female  19.0      0      0            112053  30.0000   B42        S   0
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S   0
# 889    male  26.0      0      0            111369  30.0000  C148        C   1
# 890    male  32.0      0      0            370376   7.7500   NaN        Q   1
#
# [891 rows x 12 columns]

# %%
for i in df.columns:
    
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#      Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# 0           0       2   108    1   28      1      0     523    18    147
# 1           1       0   190    0   51      1      0     596   207     81
# 2           1       2   353    0   34      0      0     669    41    147
# 3           1       0   272    0   47      1      0      49   189     55
# 4           0       2    15    1   47      0      0     472    43    147
# ..        ...     ...   ...  ...  ...    ...    ...     ...   ...    ...
# 886         0       1   548    1   35      0      0     101    85    147
# 887         1       0   303    0   24      0      0      14   153     30
# 888         0       2   413    0   88      1      2     675   131    147
# 889         1       0    81    1   34      0      0       8   153     60
# 890         0       2   220    1   42      0      0     466    30    147
#
#      Embarked  cc
# 0           2   1
# 1           0   0
# 2           2   0
# 3           2   0
# 4           2   1
# ..        ...  ..
# 886         2   1
# 887         2   0
# 888         2   0
# 889         0   1
# 890         1   1
#
# [891 rows x 12 columns]

# %%
df.corr()
# Out:
#           Survived    Pclass      Name       Sex       Age     SibSp  \
# Survived  1.000000 -0.338481 -0.057343 -0.543351 -0.112152 -0.026385
# Pclass   -0.338481  1.000000  0.052831  0.131900 -0.081541  0.078141
# Name     -0.057343  0.052831  1.000000  0.020314  0.172299 -0.035535
# Sex      -0.543351  0.131900  0.020314  1.000000  0.093455 -0.123164
# Age      -0.112152 -0.081541  0.172299  0.093455  1.000000 -0.165942
# SibSp    -0.026385  0.078141 -0.035535 -0.123164 -0.165942  1.000000
# Parch     0.081629  0.018443 -0.049105 -0.245489 -0.202667  0.423338
# Ticket   -0.164549  0.319869  0.047348  0.059372 -0.021530  0.069238
# Fare      0.333943 -0.724119 -0.053846 -0.265389 -0.052882  0.368688
# Cabin    -0.254888  0.684121  0.061959  0.096681 -0.064888  0.040729
# Embarked -0.163517  0.157112 -0.004557  0.104057 -0.130978  0.063983
# cc       -0.543351  0.131900  0.020314  1.000000  0.093455 -0.123164
#
#              Parch    Ticket      Fare     Cabin  Embarked        cc
# Survived  0.081629 -0.164549  0.333943 -0.254888 -0.163517 -0.543351
# Pclass    0.018443  0.319869 -0.724119  0.684121  0.157112  0.131900
# Name     -0.049105  0.047348 -0.053846  0.061959 -0.004557  0.020314
# Sex      -0.245489  0.059372 -0.265389  0.096681  0.104057  1.000000
# Age      -0.202667 -0.021530 -0.052882 -0.064888 -0.130978  0.093455
# SibSp     0.423338  0.069238  0.368688  0.040729  0.063983 -0.123164
# Parch     1.000000  0.020003  0.361243 -0.028324  0.038322 -0.245489
# Ticket    0.020003  1.000000 -0.168153  0.243696 -0.006041  0.059372
# Fare      0.361243 -0.168153  1.000000 -0.540116 -0.152946 -0.265389
# Cabin    -0.028324  0.243696 -0.540116  1.000000  0.193205  0.096681
# Embarked  0.038322 -0.006041 -0.152946  0.193205  1.000000  0.104057
# cc       -0.245489  0.059372 -0.265389  0.096681  0.104057  1.000000

# %%
df.corr(method="kendall")
# Out:
#           Survived    Pclass      Name       Sex       Age     SibSp  \
# Survived  1.000000 -0.323533 -0.046847 -0.543351 -0.082075  0.085915
# Pclass   -0.323533  1.000000  0.043465  0.129325 -0.087104 -0.039552
# Name     -0.046847  0.043465  1.000000  0.016596  0.110155 -0.067501
# Sex      -0.543351  0.129325  0.016596  1.000000  0.077285 -0.188694
# Age      -0.082075 -0.087104  0.110155  0.077285  1.000000 -0.144249
# SibSp     0.085915 -0.039552 -0.067501 -0.188694 -0.144249  1.000000
# Parch     0.133933 -0.021019 -0.036240 -0.246536 -0.216902  0.425241
# Ticket   -0.133512  0.278387  0.028376  0.047730 -0.023832  0.010134
# Fare      0.266229 -0.573531 -0.028169 -0.213480 -0.028008  0.358262
# Cabin    -0.293984  0.629478  0.033146  0.126075 -0.057692 -0.041123
# Embarked -0.150419  0.075442 -0.004894  0.106798 -0.116682  0.007914
# cc       -0.543351  0.129325  0.016596  1.000000  0.077285 -0.188694
#
#              Parch    Ticket      Fare     Cabin  Embarked        cc
# Survived  0.133933 -0.133512  0.266229 -0.293984 -0.150419 -0.543351
# Pclass   -0.021019  0.278387 -0.573531  0.629478  0.075442  0.129325
# Name     -0.036240  0.028376 -0.028169  0.033146 -0.004894  0.016596
# Sex      -0.246536  0.047730 -0.213480  0.126075  0.106798  1.000000
# Age      -0.216902 -0.023832 -0.028008 -0.057692 -0.116682  0.077285
# SibSp     0.425241  0.010134  0.358262 -0.041123  0.007914 -0.188694
# Parch     1.000000  0.000947  0.330360 -0.068941  0.024229 -0.246536
# Ticket    0.000947  1.000000 -0.123621  0.203415 -0.017716  0.047730
# Fare      0.330360 -0.123621  1.000000 -0.430721 -0.046889 -0.213480
# Cabin    -0.068941  0.203415 -0.430721  1.000000  0.125619  0.126075
# Embarked  0.024229 -0.017716 -0.046889  0.125619  1.000000  0.106798
# cc       -0.246536  0.047730 -0.213480  0.126075  0.106798  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
sns.set(rc = {'figure.figsize':(15,15)}) 
plt.show()

# %%
df.corrwith(df['Survived']).sort_values(ascending=False).plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
y = df['Survived']

# %%
X = df[df.columns[1:]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1 = LogisticRegression(random_state =100,C=1.2, penalty='l2')

# %%
model1.fit(X_train,y_train)
# Out:
# D:\ANACONDA\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.2, random_state=100)

# %%
y_predTr = model1.predict(X_train)
y_predTe = model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_train,y_predTr))
c = classification_report(y_train,y_predTr)
print(c)
# Out:
# [[332  50]
#  [ 81 160]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       382
#            1       0.76      0.66      0.71       241
#
#     accuracy                           0.79       623
#    macro avg       0.78      0.77      0.77       623
# weighted avg       0.79      0.79      0.79       623

# %%
print(confusion_matrix(y_test,y_predTe))
c = classification_report(y_test,y_predTe)
print(c)
# Out:
# [[143  24]
#  [ 34  67]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       167
#            1       0.74      0.66      0.70       101
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.76      0.76       268
# weighted avg       0.78      0.78      0.78       268

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import tree

# %%
model2 = DecisionTreeClassifier(criterion='entropy')

model2.fit(X_train,y_train)
y_predTr = model2.predict(X_train)
y_predTe = model2.predict(X_test)
print(confusion_matrix(y_train,y_predTr))
c = classification_report(y_train,y_predTr)
print(c)
print(30*'-')
print(confusion_matrix(y_test,y_predTe))
c = classification_report(y_test,y_predTe)
print(c)
# Out:
# [[382   0]
#  [  0 241]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00       241
#
#     accuracy                           1.00       623
#    macro avg       1.00      1.00      1.00       623
# weighted avg       1.00      1.00      1.00       623
#
# ------------------------------
# [[134  33]
#  [ 34  67]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       167
#            1       0.67      0.66      0.67       101
#
#     accuracy                           0.75       268
#    macro avg       0.73      0.73      0.73       268
# weighted avg       0.75      0.75      0.75       268

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20))
tree.plot_tree(model2, feature_names=X.columns, class_names='Survived', filled = True)
plt.savefig('my.pdf')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3 = RandomForestClassifier(n_estimators=100)
model3.fit(X_train,y_train)
y_predTr = model3.predict(X_train)
y_predTe = model3.predict(X_test)
print(confusion_matrix(y_train,y_predTr))
c = classification_report(y_train,y_predTr)
print(c)
print(30*'-')
print(confusion_matrix(y_test,y_predTe))
c = classification_report(y_test,y_predTe)
print(c)
# Out:
# [[382   0]
#  [  0 241]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00       241
#
#     accuracy                           1.00       623
#    macro avg       1.00      1.00      1.00       623
# weighted avg       1.00      1.00      1.00       623
#
# ------------------------------
# [[160   7]
#  [ 30  71]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90       167
#            1       0.91      0.70      0.79       101
#
#     accuracy                           0.86       268
#    macro avg       0.88      0.83      0.84       268
# weighted avg       0.87      0.86      0.86       268

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
mod_lis = [model1,model2,model3]

# %%
def training_resyl(li):
    for model in li:
        model = RandomForestClassifier(n_estimators=100)
        model.fit(X_train,y_train)
        y_predTr = model.predict(X_train)
        y_predTe = model.predict(X_test)
        print(confusion_matrix(y_train,y_predTr))
        c = classification_report(y_train,y_predTr)
        print(c)
        print(10*'-')
        print(confusion_matrix(y_test,y_predTe))
        c = classification_report(y_test,y_predTe)
        print(c)
        plot_confusion_matrix(model, X_test, y_test)  
        plt.show()
        
        print(40*'*-*')

# %%
training_resyl(mod_lis)
# Out:
# [[382   0]
#  [  0 241]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00       241
#
#     accuracy                           1.00       623
#    macro avg       1.00      1.00      1.00       623
# weighted avg       1.00      1.00      1.00       623
#
# ----------
# [[157  10]
#  [ 31  70]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88       167
#            1       0.88      0.69      0.77       101
#
#     accuracy                           0.85       268
#    macro avg       0.86      0.82      0.83       268
# weighted avg       0.85      0.85      0.84       268
# D:\ANACONDA\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# *-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-*
# [[382   0]
#  [  0 241]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00       241
#
#     accuracy                           1.00       623
#    macro avg       1.00      1.00      1.00       623
# weighted avg       1.00      1.00      1.00       623
#
# ----------
# [[154  13]
#  [ 31  70]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.88       167
#            1       0.84      0.69      0.76       101
#
#     accuracy                           0.84       268
#    macro avg       0.84      0.81      0.82       268
# weighted avg       0.84      0.84      0.83       268
# D:\ANACONDA\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# *-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-*
# [[382   0]
#  [  0 241]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       382
#            1       1.00      1.00      1.00       241
#
#     accuracy                           1.00       623
#    macro avg       1.00      1.00      1.00       623
# weighted avg       1.00      1.00      1.00       623
#
# ----------
# [[157  10]
#  [ 32  69]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88       167
#            1       0.87      0.68      0.77       101
#
#     accuracy                           0.84       268
#    macro avg       0.85      0.81      0.82       268
# weighted avg       0.85      0.84      0.84       268
# D:\ANACONDA\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# *-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-**-*

# %%
solver : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

# %%
{'penalty': 'l1', 
'penalty': 'l2'},
# Out:
# ({'penalty': 'l2'},)

# %%
max_iter = [10,14,50,60,80,100,150]

# %%
C = [0.6,0.9,1.0,1.5, 1.8,2.5]

# %%
LogisticRegression(C=i,max_iter=10)
LogisticRegression(C=i,max_iter=10)
LogisticRegression(C=i,max_iter=10)
LogisticRegression(C=i,max_iter=10)
LogisticRegression(C=i,max_iter=10)
# Out:
# LogisticRegression(C=0.6, max_iter=10)

# %%
for i in C:
    LogisticRegression(C=i,max_iter=10)

# %%
[:200]   [200:]  [200:200*200]
# Out:
#   File "C:\Users\HAMNAI~1\AppData\Local\Temp/ipykernel_16016/3050117029.py", line 1
#     [:200]   [200:]  [200:200*200]
#      ^
# SyntaxError: invalid syntax

# %%
for i in
# Out:
#   File "C:\Users\HAMNAI~1\AppData\Local\Temp/ipykernel_16016/3996493703.py", line 1
#     for i in
#              ^
# SyntaxError: invalid syntax
